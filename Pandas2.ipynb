# %%
## Importing padas, numpy and matplotlib.pyplot
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
## importing data frame to df
df = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv')

# %%
## Inspecting first 5 rows
df.head()
# Out:
#    Unnamed: 0     Id     Name  Year Gender State  Count
# 0       11349  11350     Emma  2004      F    AK     62
# 1       11350  11351  Madison  2004      F    AK     48
# 2       11351  11352   Hannah  2004      F    AK     46
# 3       11352  11353    Grace  2004      F    AK     44
# 4       11353  11354    Emily  2004      F    AK     41

# %%
## Inspecting data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1016395 entries, 0 to 1016394
# Data columns (total 7 columns):
# Unnamed: 0    1016395 non-null int64
# Id            1016395 non-null int64
# Name          1016395 non-null object
# Year          1016395 non-null int64
# Gender        1016395 non-null object
# State         1016395 non-null object
# Count         1016395 non-null int64
# dtypes: int64(4), object(3)
# memory usage: 54.3+ MB

# %%
## Answer 1 : droping Unnamed column
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
## Verifying Unnamed column has been droppped
df.head()
# Out:
#       Id     Name  Year Gender State  Count
# 0  11350     Emma  2004      F    AK     62
# 1  11351  Madison  2004      F    AK     48
# 2  11352   Hannah  2004      F    AK     46
# 3  11353    Grace  2004      F    AK     44
# 4  11354    Emily  2004      F    AK     41

# %%
## Answer 2 : Gender distribution
df.Gender.value_counts()
# Out:
# F    558846
# M    457549
# Name: Gender, dtype: int64

# %%
# %matplotlib inline

# %%
##  Answer 2 cont : Gender Distribution Graph
df.Gender.value_counts().plot(kind='bar')

# %%
## Answer 3:  Top 5 common names
df.groupby(['Name']).Count.sum().sort_values(ascending = False).head()
# Out:
# Name
# Jacob       242874
# Emma        214852
# Michael     214405
# Ethan       209277
# Isabella    204798
# Name: Count, dtype: int64

# %%
## Answer 4: median name occured in dataset 
df2 = df.groupby('Name').Count.sum()
df2[df2 == df2.median()]
# Out:
# Name
# Aishani       49
# Alara         49
# Alysse        49
# Ameir         49
# Anely         49
# Antonina      49
# Aveline       49
# Aziah         49
# Baily         49
# Caleah        49
# Carlota       49
# Cristine      49
# Dahlila       49
# Darvin        49
# Deante        49
# Deserae       49
# Devean        49
# Elizah        49
# Emmaly        49
# Emmanuela     49
# Envy          49
# Esli          49
# Fay           49
# Gurshaan      49
# Hareem        49
# Iven          49
# Jaice         49
# Jaiyana       49
# Jamiracle     49
# Jelissa       49
#               ..
# Kyndle        49
# Kynsley       49
# Leylanie      49
# Maisha        49
# Malillany     49
# Mariann       49
# Marquell      49
# Maurilio      49
# Mckynzie      49
# Mehdi         49
# Nabeel        49
# Nalleli       49
# Nassir        49
# Nazier        49
# Nishant       49
# Rebecka       49
# Reghan        49
# Ridwan        49
# Riot          49
# Rubin         49
# Ryatt         49
# ...

# %%
## Answer 5 : Distribution of male and female born count by states ( as DataFrame)
g = df.groupby(['State','Gender']).Count.count().reset_index()
g
# Out:
#     State Gender  Count
# 0      AK      F   2404
# 1      AK      M   2587
# 2      AL      F   9878
# 3      AL      M   8419
# 4      AR      F   7171
# 5      AR      M   6475
# 6      AZ      F  14518
# 7      AZ      M  10820
# 8      CA      F  45144
# 9      CA      M  31637
# 10     CO      F  11424
# 11     CO      M   9183
# 12     CT      F   6575
# 13     CT      M   5733
# 14     DC      F   3053
# 15     DC      M   3000
# 16     DE      F   2549
# 17     DE      M   2440
# 18     FL      F  25781
# 19     FL      M  20070
# 20     GA      F  19385
# 21     GA      M  15454
# 22     HI      F   3255
# 23     HI      M   3546
# 24     IA      F   7131
# 25     IA      M   6307
# 26     ID      F   4918
# 27     ID      M   4833
# 28     IL      F  21268
# 29     IL      M  16828
# ..    ...    ...    ...
# 72     OK      F   9519
# 73     OK      M   8138
# 74     OR      F   8604
# 75     OR      M   7333
# 76     PA      F  17480
# 77     PA      M  14171
# ...

# %%
## Answer 5 cont : Distribution of male and female born count by states ( as Series)
g = df.groupby(['State','Gender']).Count.count()
g
# Out:
# State  Gender
# AK     F          2404
#        M          2587
# AL     F          9878
#        M          8419
# AR     F          7171
#        M          6475
# AZ     F         14518
#        M         10820
# CA     F         45144
#        M         31637
# CO     F         11424
#        M          9183
# CT     F          6575
#        M          5733
# DC     F          3053
#        M          3000
# DE     F          2549
#        M          2440
# FL     F         25781
#        M         20070
# GA     F         19385
#        M         15454
# HI     F          3255
#        M          3546
# IA     F          7131
#        M          6307
# ID     F          4918
#        M          4833
# IL     F         21268
#        M         16828
#                  ...
# OK     F          9519
#        M          8138
# OR     F          8604
#        M          7333
# PA     F         17480
#        M         14171
# RI     F          2558
#        M          2468
# ...

# %%
df.head()
# Out:
#       Id     Name  Year Gender State  Count
# 0  11350     Emma  2004      F    AK     62
# 1  11351  Madison  2004      F    AK     48
# 2  11352   Hannah  2004      F    AK     46
# 3  11353    Grace  2004      F    AK     44
# 4  11354    Emily  2004      F    AK     41

# %%
df[(df.Gender == 'M') &(df.Year == 2005)].Year.value_counts()
# Out:
# 2005    39298
# Name: Year, dtype: int64
